-- %%
-- Volumes ggerenciados
create volume if not exists projeto_databricks.default.mnt;

-- criando o Schemas e volumes eternos
CREATE SCHEMA IF NOT EXISTS projeto_databricks.azure;
CREATE EXTERNAL VOLUME projeto_databricks.azure.projeto1
COMMENT 'Volume Externno na Azure'
LOCATION 'abfss://uc-ext-azure@projetodatabricksken.dfs.core.windows.net/projeto1'

CREATE EXTERNAL VOLUME projeto_databricks.azure.projeto2
COMMENT 'Volume Externno na Azure'
LOCATION 'abfss://uc-ext-azure@projetodatabricksken.dfs.core.windows.net/projeto2'

-- drop teste para testar o acesso e segurança externna
drop volume projeto_databricks.azure.projeto2;
drop schema projeto_databricks.azure;
